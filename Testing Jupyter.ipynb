# %% [markdown]
# # Sample Headline
#
# *Note: This text will be italicized.*
#
# ## Another Headline (H2)
#
# This is a normal paragraph. Now for some Lorem Ipsum. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Vestibulum sapien orci, gravida eget rutrum ac, tempor et ipsum. Nunc vel nulla faucibus lorem egestas feugiat ut quis erat.
#
# Basic formatting of *italics* and **bold** is supported. This *can be **nested** like* so.
#
# ### What this notebook shows
#
# 1. How to get started with notebooks
# 2. How to execute code
# 3. How to add markdown
# 4. And... other stuff

# %%
name = "Mina"

# %%
name
# Out:
# 'Mina'

# %%
name = "Mike"

# %% [markdown]
# ! before a command gets treated as a bash command

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ---------------
# annotated-doc             0.0.4
# annotated-types           0.7.0
# anyio                     4.11.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.0.5
# attrs                     23.2.0
# babel                     2.17.0
# beautifulsoup4            4.11.2
# bleach                    6.3.0
# blinker                   1.4
# bs4                       0.0.2
# cachetools                6.2.2
# certifi                   2025.4.26
# cffi                      1.17.1
# chardet                   4.0.0
# charset-normalizer        3.0.1
# click                     8.3.1
# coloredlogs               7.3
# comm                      0.2.3
# command-not-found         0.3
# contourpy                 1.3.2
# cryptography              3.4.8
# curl_cffi                 0.11.1
# cycler                    0.12.1
# dbus-python               1.2.18
# debugpy                   1.8.17
# decorator                 5.2.1
# defusedxml                0.7.1
# distlib                   0.4.0
# distro                    1.7.0
# distro-info               1.1+ubuntu0.2
# eventkit                  1.0.3
# exceptiongroup            1.2.1
# executing                 2.2.1
# fastapi                   0.121.3
# fastjsonschema            2.21.2
# filelock                  3.25.0
# fonttools                 4.39.3
# fqdn                      1.5.1
# frozendict                2.4.6
# fsspec                    2023.12.2
# gdspy                     1.4
# google-auth               2.43.0
# google-genai              1.52.0
# gyp                       0.1
# h11                       0.16.0
# html5lib                  1.1
# httpcore                  1.0.9
# httplib2                  0.20.2
# httpx                     0.28.1
# humanfriendly             10.0
# ib-insync                 0.9.86
# idna                      3.4
# img2pdf                   0.4.2
# importlib-metadata        4.6.4
# ipykernel                 7.1.0
# ipython                   8.37.0
# isoduration               20.11.0
# jedi                      0.19.2
# jeepney                   0.7.1
# Jinja2                    3.1.6
# json5                     0.12.1
# jsonpointer               3.0.0
# jsonschema                4.25.1
# jsonschema-specifications 2025.9.1
# jupyter_client            8.6.3
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.5.0
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# keyring                   23.5.0
# kiwisolver                1.4.4
# lark                      1.3.1
# launchpadlib              1.10.16
# lazr.restfulclient        0.14.4
# lazr.uri                  1.0.6
# lxml                      4.8.0
# MarkupSafe                2.1.4
# matplotlib                3.10.7
# matplotlib-inline         0.2.1
# mistune                   3.1.4
# more-itertools            8.10.0
# multitasking              0.0.11
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# netifaces                 0.11.0
# networkx                  3.2.1
# notebook                  7.5.0
# notebook_shim             0.2.4
# numpy                     2.2.6
# oauthlib                  3.2.0
# ocrmypdf                  13.4.0+dfsg
# olefile                   0.46
# outcome                   1.3.0.post0
# overrides                 7.7.0
# packaging                 25.0
# pandas                    2.2.3
# pandocfilters             1.5.1
# parso                     0.8.5
# pdfminer.six              -VERSION-
# peewee                    3.18.1
# pexpect                   4.9.0
# pikepdf                   5.0.1+dfsg
# Pillow                    9.0.1
# pip                       22.0.2
# platformdirs              4.3.8
# pluggy                    0.13.0
# prometheus_client         0.23.1
# prompt_toolkit            3.0.52
# protobuf                  6.31.1
# psutil                    5.9.8
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pyasn1                    0.6.1
# pyasn1_modules            0.4.2
# pycairo                   1.20.1
# pycparser                 2.22
# pydantic                  2.12.4
# pydantic_core             2.41.5
# Pygments                  2.19.2
# PyGObject                 3.42.1
# PyJWT                     2.3.0
# pyparsing                 3.2.5
# PySocks                   1.7.1
# python-apt                2.4.0+ubuntu4.1
# python-dateutil           2.8.2
# python-discovery          1.1.1
# python-json-logger        4.0.0
# python-pptx               0.6.21
# pytz                      2025.2
# PyYAML                    6.0
# pyzmq                     27.1.0
# referencing               0.37.0
# regex                     2023.12.25
# reportlab                 3.6.8
# requests                  2.32.3
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.30.0
# rsa                       4.9.1
# ruamel.yaml               0.17.21
# ruamel.yaml.clib          0.2.7
# SecretStorage             3.3.1
# selenium                  4.21.0
# Send2Trash                1.8.3
# setuptools                59.6.0
# six                       1.16.0
# sniffio                   1.3.1
# sortedcontainers          2.4.0
# soupsieve                 2.4
# stack-data                0.6.3
# starlette                 0.50.0
# sympy                     1.12
# systemd-python            234
# tenacity                  9.1.2
# terminado                 0.18.1
# tinycss2                  1.4.0
# tomli                     2.3.0
# tornado                   6.5.2
# tqdm                      4.57.0
# traitlets                 5.14.3
# trio                      0.25.1
# trio-websocket            0.11.1
# typing_extensions         4.15.0
# typing-inspection         0.4.2
# tzdata                    2025.2
# ubuntu-advantage-tools    27.12
# ufw                       0.36.1
# unattended-upgrades       0.1
# uri-template              1.3.0
# urllib3                   1.26.14
# uvicorn                   0.38.0
# virtualenv                21.1.0
# wadllib                   1.3.6
# wcwidth                   0.2.14
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# websockets                15.0.1
# wheel                     0.37.1
# wsproto                   1.2.0
# xdot                      1.2
# XlsxWriter                3.1.0
# yfinance                  0.2.61
# zipp                      1.0.0

# %% [markdown]
# We have commands called "magics" indicated by % for 1 line or %% for 2 lines. One % means commands args come from that 1 line (line magics), and %% mean the entire cell will be taken as an argument (cell magics)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %subshell  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %pwd
# Out:
# '/mnt/c/Users/MinaG/Python Tutorials'

# %%
# %ls -la
# Out:
# total 48
# drwxrwxrwx 1 minagawargious minagawargious  4096 Mar  8 14:39  ./
# drwxrwxrwx 1 minagawargious minagawargious  4096 Mar  7 21:51  ../
# drwxrwxrwx 1 minagawargious minagawargious  4096 Mar  7 21:28  .git/
# -rwxrwxrwx 1 minagawargious minagawargious    39 Mar  7 21:28  .gitignore*
# drwxrwxrwx 1 minagawargious minagawargious  4096 Mar  8 03:43  .ipynb_checkpoints/
# drwxrwxrwx 1 minagawargious minagawargious  4096 Mar  7 21:21  Environments/
# drwxrwxrwx 1 minagawargious minagawargious  4096 Mar  7 17:48  My_Module_Dir/
# -rwxrwxrwx 1 minagawargious minagawargious 19951 Mar  8 14:39 'Testing Jupyter.ipynb'*
# -rwxrwxrwx 1 minagawargious minagawargious  1494 Mar  6 21:01  conditionals_and_booleans.py*
# -rwxrwxrwx 1 minagawargious minagawargious  1414 Mar  6 14:54  dictionaries.py*
# -rwxrwxrwx 1 minagawargious minagawargious  2399 Mar  7 16:11  functions.py*
# -rwxrwxrwx 1 minagawargious minagawargious  3392 Mar  6 17:22  lists__tuples_sets.py*
# -rwxrwxrwx 1 minagawargious minagawargious  2776 Mar  7 14:57  loops_and_iterations.py*
# -rwxrwxrwx 1 minagawargious minagawargious  1529 Mar  7 18:26  module_import_test.py*
# -rwxrwxrwx 1 minagawargious minagawargious   518 Mar  6 12:47  numbers_test.py*
# -rwxrwxrwx 1 minagawargious minagawargious  2497 Mar  6 15:13  strings.py*

# %%
# %matplotlib inline

# %%
"""
Simple demo of a scatter plot.
"""

import numpy as np
import matplotlib.pyplot as plt

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/YJC6ldI3hWk" frameborder="0" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/YJC6ldI3hWk" frameborder="0" allowfullscreen></iframe>

# %%
# %%timeit
square_evens = [n*n for n in range(10000)]
# Out:
# 289 μs ± 9.06 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10, 5))
df.head()
# Out:
#           0         1         2         3         4
# 0 -0.433361  0.787432  0.685999  1.042838  0.591716
# 1 -1.672734  0.864569 -0.610795  0.177185 -0.105622
# 2  0.070130 -0.821536 -1.721234 -0.622797 -0.263835
# 3  0.454511 -1.808417  1.056942  1.010978  1.604275
# 4 -0.495865 -1.029425 -0.434010 -0.964255  0.652862
